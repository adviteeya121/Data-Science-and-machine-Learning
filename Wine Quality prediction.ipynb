# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading Dataset

# %%
df=pd.read_csv("winequalityN.csv")
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Information regarding data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %% [markdown]
# # Changing the Datatype of type column

# %%
df["type"]=df["type"].astype("category")

# %% [markdown]
# memory size is reduced after changing the datatype of 'type' column as show in below

# %% [markdown]
# # More info about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   category
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: category(1), float64(11), int64(1)
# memory usage: 615.7 KB

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Checking for null values

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# # Filling the null values

# %%
df["fixed acidity"]=df["fixed acidity"].fillna(df["fixed acidity"].mean())

# %%
df["volatile acidity"]=df["volatile acidity"].fillna(df["volatile acidity"].mean())

# %%
df["citric acid"]=df["citric acid"].fillna(df["citric acid"].mean())

# %%
df["residual sugar"]=df["residual sugar"].fillna(df["residual sugar"].mean())

# %%
df["chlorides"]=df["chlorides"].fillna(df["chlorides"].mean())

# %%
df["pH"]=df["pH"].fillna(df["pH"].mean())

# %%
df["sulphates"]=df["sulphates"].fillna(df["sulphates"].mean())

# %%
# Again Checking the Null Values
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Checking the co relation between columns

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219918     0.323349
# volatile acidity           0.219918          1.000000    -0.377759
# citric acid                0.323349         -0.377759     1.000000
# residual sugar            -0.112219         -0.196578     0.142451
# chlorides                  0.298282          0.377122     0.039310
# free sulfur dioxide       -0.283237         -0.353055     0.133426
# total sulfur dioxide      -0.329409         -0.414706     0.195148
# density                    0.458941          0.271107     0.096307
# pH                        -0.251683          0.260283    -0.328354
# sulphates                  0.300225          0.225313     0.057564
# alcohol                   -0.095560         -0.038215    -0.010431
# quality                   -0.076967         -0.265838     0.085699
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.pairplot(df.corr())

# %% [markdown]
# # Removing the noisy columns according to quality column

# %%
df=df[["citric acid","free sulfur dioxide","pH","sulphates","alcohol","quality"]]
df
# Out:
#       citric acid  free sulfur dioxide    pH  sulphates  alcohol  quality
# 0            0.36                 45.0  3.00   0.450000      8.8        6
# 1            0.34                 14.0  3.30   0.490000      9.5        6
# 2            0.40                 30.0  3.26   0.440000     10.1        6
# 3            0.32                 47.0  3.19   0.400000      9.9        6
# 4            0.32                 47.0  3.19   0.400000      9.9        6
# ...           ...                  ...   ...        ...      ...      ...
# 6492         0.08                 32.0  3.45   0.580000     10.5        5
# 6493         0.10                 39.0  3.52   0.531215     11.2        6
# 6494         0.13                 29.0  3.42   0.750000     11.0        6
# 6495         0.12                 32.0  3.57   0.710000     10.2        5
# 6496         0.47                 18.0  3.39   0.660000     11.0        6
#
# [6497 rows x 6 columns]

# %% [markdown]
# # Plotting graphs

# %%
df
# Out:
#       citric acid  free sulfur dioxide    pH  sulphates  alcohol  quality
# 0            0.36                 45.0  3.00   0.450000      8.8        6
# 1            0.34                 14.0  3.30   0.490000      9.5        6
# 2            0.40                 30.0  3.26   0.440000     10.1        6
# 3            0.32                 47.0  3.19   0.400000      9.9        6
# 4            0.32                 47.0  3.19   0.400000      9.9        6
# ...           ...                  ...   ...        ...      ...      ...
# 6492         0.08                 32.0  3.45   0.580000     10.5        5
# 6493         0.10                 39.0  3.52   0.531215     11.2        6
# 6494         0.13                 29.0  3.42   0.750000     11.0        6
# 6495         0.12                 32.0  3.57   0.710000     10.2        5
# 6496         0.47                 18.0  3.39   0.660000     11.0        6
#
# [6497 rows x 6 columns]

# %%
df.corr()
# Out:
#                      citric acid  free sulfur dioxide        pH  sulphates  \
# citric acid             1.000000             0.133426 -0.328354   0.057564
# free sulfur dioxide     0.133426             1.000000 -0.145116  -0.188471
# pH                     -0.328354            -0.145116  1.000000   0.191075
# sulphates               0.057564            -0.188471  0.191075   1.000000
# alcohol                -0.010431            -0.179838  0.120939  -0.003261
# quality                 0.085699             0.055463  0.019356   0.038713
#
#                       alcohol   quality
# citric acid         -0.010431  0.085699
# free sulfur dioxide -0.179838  0.055463
# pH                   0.120939  0.019356
# sulphates           -0.003261  0.038713
# alcohol              1.000000  0.444319
# quality              0.444319  1.000000

# %%
sns.catplot(x="quality",y="citric acid",data=df,kind="swarm")
plt.title("citric acid vs quality",fontsize=15)
plt.xlabel("quality",fontsize=15)
plt.ylabel("citric acid",fontsize=15)
# Out:
# Text(0.42499999999999716, 0.5, 'citric acid')

# %%
sns.catplot(x="quality",y="alcohol",data=df,kind="boxen")
plt.title("alcohol vs quality",fontsize=15)
plt.xlabel("quality",fontsize=15)
plt.ylabel("alcohol",fontsize=15)
# Out:
# Text(10.049999999999997, 0.5, 'alcohol')

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop("quality",axis="columns")

# %%
y=df["quality"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print('model score is : '+ str(model.score(x_test,y_test)*100))
# Out:
# model score is : 67.44615384615385

# %%
predict=model.predict(x_test)
predict
# Out:
# array([6, 7, 6, ..., 6, 5, 7])

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cv=confusion_matrix(predict,y_test)
cv
# Out:
# array([[  0,   0,   0,   0,   0,   0,   0],
#        [  0,   6,   2,   2,   0,   1,   0],
#        [  6,  24, 359, 150,   8,   1,   0],
#        [  3,  22, 124, 554,  98,  15,   0],
#        [  0,   1,   6,  50, 158,   7,   2],
#        [  0,   0,   0,   4,   3,  19,   0],
#        [  0,   0,   0,   0,   0,   0,   0]])

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cv,annot=True,fmt="g")
plt.title("Confusion matrix representation",fontsize=15)
plt.xlabel("Actual Values",fontsize=15)
plt.ylabel("Predicted Values",fontsize=15)
# Out:
# Text(69.0, 0.5, 'Predicted Values')
